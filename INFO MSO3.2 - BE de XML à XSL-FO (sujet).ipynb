# %% [markdown]
# # <center>INFO MSO 3.2 - Représentation et manipulation de données structurées</center>

# %% [markdown]
# ## <center style="color: #66d">BE - Application XML, Import, Validation, Transformation, Impression</center>

# %% [markdown]
# ### Déroulement de la séance
#
# Ce travail s'effectue par binômes. Merci de vous organiser et de prendre les coordonnées de votre binôme pour pouvoir finir si nécessaire le travail après la séance.
#
# Les livrables qui vous seront demandés pour ce BE devront faire l'objet d'un UNIQUE fichier zippé (.zip, .gz, .tgz, .tar, .7z - les formats exotiques non listés ici ne seront pas pris en compte) et déposés sur le serveur moodle dans la zone "Bureau d'Etude".
#
# Le compte-rendu est à déposer <a href="https://pedagogie3.ec-lyon.fr/mod/assign/view.php?id=36070">[ici]</a> par l'un OU l'autre membre du binôme sur le serveur moodle dans la rubrique <i>Bureau d'Etude</i> du cours <i>INFO MSO 3.2 - Représentation et manipulation de données structurées</i>.
#
# Au moment du dépôt, merci de bien vouloir rédiger le champ Titre sous la forme :
#
#           CR <nom eleve 1> - <nom eleve 2>

# %% [markdown]
# ### 1. Définition de type d'un document XML
#
# Avec le sujet, vous avez trouvé un fichier de données nommé <tt>regularite-mensuelle-tgv.csv</tt> contenant des informations sur la régularité des TGV entre septembre 2011 et juin 2015.
#
# Vous pouvez observer la nature et la structure des informations que contient ce fichier à l'aide de votre tableur préféré, ou à défaut avec un éditeur de texte.
#
# L'objectif est de créer un document XML correspondant à une _application XML_ permettant de stocker ces mêmes données, en évitant au maximum la redondance d'information. Cette application est décrite par la DTD suivante :

# %% [raw]
# <!DOCTYPE regularite-tgv [
#     <!ELEMENT regularite-tgv (axe+)>
#
#     <!ELEMENT axe (gare-depart+)>
#     <!ATTLIST axe nom CDATA #REQUIRED>
#
#     <!ELEMENT gare-depart (gare-arrivee+)>
#     <!ATTLIST gare-depart nom CDATA #REQUIRED>
#
#     <!ELEMENT gare-arrivee (mesure+)>
#     <!ATTLIST gare-arrivee nom CDATA #REQUIRED>
#
#     <!ELEMENT mesure EMPTY>
#     <!ATTLIST mesure
#         annee         CDATA #REQUIRED
#         mois          CDATA #REQUIRED
#         trains-prevus CDATA #REQUIRED
#         trains-ok     CDATA #REQUIRED
#         annules       CDATA #REQUIRED
#         retards       CDATA #REQUIRED
#         regularite    CDATA #REQUIRED
#         commentaire   CDATA #REQUIRED
#         >
# ]>

# %% [markdown]
# <b>Q1. Modèle de document XML :</b>
# <div style="background-color:#eef;padding:10px;border-radius:3px">
# Donner un exemple de document XML le plus simple possible correspondant à la structure préconisée par cette DTD
#     (c'est-à-dire avec un seul élément correspondant à chacun des contenus obligatoires).
# </div>

# %% [raw]
# <?xml version="1.0" encoding="UTF-8"?>
# <regularite-tgv>
#     <axe nom="Nord">
#         <gare-depart nom="PARIS NORD">
#             <gare-arrivee nom="DOUAI">
#                 <mesure
#                     annee="2014"
#                     mois="03"
#                     trains-prevus="196"
#                     trains-ok="196"
#                     annules="0"
#                     retards="11"
#                     regularite="94.4"
#                     commentaire=""
#                 />
#             </gare-arrivee>
#         </gare-depart>
#     </axe>
# </regularite-tgv>

# %% [markdown]
# ### 2. Validation d'un document XML
#
# Il existe un certain nombre de sites en ligne permettant la validation d'un document XML à l'aide d'une DTD. Une simple recherche avec les mots-clés <i>XML validator</i> pourra vous en convaincre.
# Il est toutefois beaucoup plus pratique de valider ses documents à l'aide de quelques lignes de code maison, comme il vous est proposé ci-dessous.
#
# <b>Q2. Validation du document d'exemple :</b>
# <div style="background-color:#eef;padding:10px;border-radius:3px"><ul>
# <li>Inclure au document simplifié que vous venez de définir la DTD fournie sous forme de DTD interne,</li>
#     <li>enregistrer ce document sous le nom <a href="question-2.xml"><tt>question-2.xml</tt></a>,</li>
#     <li>puis valider le document obtenu à l'aide d'un programme python que vous développerez à l'aide du module <a href="http://lxml.de/validation.html"><tt>lxml</tt></a>.</li>
#     </ul>
# </div>

# %%
from lxml import etree


def validate_tag(element, expected_tag: str) -> bool:
    if element.tag != expected_tag:
        return False
    return True

def validate_attribs(element, mandatory_attribs: list[str] = [], optional_attribs: list[str] = []) -> bool:
    attribs = element.attrib

    for key in mandatory_attribs:
        if key not in attribs:
            return False
        
    for key in attribs:
        if key not in mandatory_attribs and key not in optional_attribs:
            return False
    
    return True


def validate(filename):
    try:
        with open(filename, 'r') as f:
            xml = f.read()
            regularite_tgv = etree.fromstring(xml)
    except etree.XMLSyntaxError as e:
        print(e)
        return False
    
    if not validate_tag(regularite_tgv, 'regularite-tgv'):
        return False
    if not validate_attribs(regularite_tgv):
        return False
    
    for axe in regularite_tgv:
        if not validate_tag(axe, 'axe'):
            return False
        
        if not validate_attribs(axe, ['nom']):
            return False
        
        for gare_depart in axe:
            if not validate_tag(gare_depart, 'gare-depart'):
                return False
            
            if not validate_attribs(gare_depart, ['nom']):
                return False
            
            for gare_arrivee in gare_depart:
                if not validate_tag(gare_arrivee, 'gare-arrivee'):
                    return False
                
                if not validate_attribs(gare_arrivee, ['nom']):
                    return False
                
                for mesure in gare_arrivee:
                    if not validate_tag(mesure, 'mesure'):
                        return False
                    
                    if not validate_attribs(mesure, [        
                            'annee',
                            'mois',
                            'trains-prevus',
                            'trains-ok',
                            'annules',
                            'retards',
                            'regularite',
                            'commentaire',
                        ]
                    ):
                        return False
                    
                    if len(mesure) != 0:
                        return False

    return True

validate('question-2.xml')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 80
#      76                         return False
#      78     return True
# ---> 80 validate('question-2.xml')
#
# Cell In[1], line 27, in validate(filename)
#      25     with open(filename, 'r') as f:
#      26         xml = f.read()
# ---> 27         regularite_tgv = etree.fromstring(xml)
#      28 except etree.XMLSyntaxError as e:
#      29     print(e)
#
# File src/lxml/etree.pyx:3264, in lxml.etree.fromstring()
#
# File src/lxml/parser.pxi:1984, in lxml.etree._parseMemoryDocument()
#
# ValueError: Unicode strings with encoding declaration are not supported. Please use bytes input or XML fragments without declaration.

# %% [markdown]
# ### 3. Création d'un document XML
#
# <b>Q3. Import :</b>
# <div style="background-color:#eef;padding:10px;border-radius:3px">
# En vous reportant au mode d'emploi du module python nommé <a href="https://docs.python.org/3/library/csv.html"><tt>csv</tt></a> pour la lecture du fichier de données, et <a href="http://lxml.de/tutorial.html"><tt>lxml.etree</tt></a> pour la création de l'arbre XML, compléter ci-dessous le programme python de manière à créer un document XML conforme à la DTD préconisée et contenant les données du fichier CSV fourni. Exécuter ce programme pour créer le document XML que vous nommerez
#     <a href="question-3.xml"><tt>question-3.xml</tt></a>.
# </div>

# %%
# Génération du document XML 
from lxml import etree
import csv

# Lecture des informations
axes = {}
with open("regularite-mensuelle-tgv.csv",'r',encoding='utf-8') as csvfile:
    reader = csv.reader(csvfile, delimiter=';', quotechar='"')
    header = next(reader)
    entry = {}
    for row in reader:
        annee, mois = row[0].split('-')
        axe = row[1]
        gare_depart = row[2]
        gare_arrivee = row[3]
        trains_prevus = row[4]
        trains_ok = row[5]
        annules = row[6]
        retards = row[7]
        regularite = row[8]
        commentaire = row[9]

        existing_axe = axes.get(axe, {}) 
        existing_gare_depart = existing_axe.get(gare_depart, {})
        existing_gare_arrivee = existing_gare_depart.get(gare_arrivee, [])

        mesure = {
            'annee': annee,
            'mois': mois,
            'trains-prevus': trains_prevus,
            'trains-ok': trains_ok,
            'annules': annules,
            'retards': retards,
            'regularite': regularite,
            'commentaire': commentaire,
        }

        existing_gare_arrivee.append(mesure)

        existing_gare_depart[gare_arrivee] = existing_gare_arrivee

        existing_axe[gare_depart] = existing_gare_depart

        axes[axe] = existing_axe

# création de l'arbre XML en mémoire
root = etree.fromstring('<regularite-tgv/>')
for a in axes:
    axe = axes[a]
    axe_element = etree.SubElement(root, 'axe', nom=a)
    
    for gare_depart in axe:
        gare_depart_element = etree.SubElement(axe_element, 'gare-depart', nom=gare_depart)
        for gare_arrivee in axe[gare_depart]:
            gare_arrivee_element = etree.SubElement(gare_depart_element, 'gare-arrivee', nom=gare_arrivee)
            for mesure in axe[gare_depart][gare_arrivee]:
                mesure_element = etree.SubElement(gare_arrivee_element, 'mesure', mesure)

# sérialisation dans un fichier
with open('question-3.xml', 'wb') as f:
    f.write(etree.tostring(root.getroottree(), pretty_print=True, encoding='utf-8'))

# %% [markdown]
# <b>Q4. Validation du document XML :</b>
# <div style="background-color:#eef;padding:10px;border-radius:3px">
# Comme pour le document simple inclure de la même manière que précédemment la DTD fournie sous forme de DTD interne au document généré, puis valider ce document.
# </div>
# <p><b>N.B.</b> Le document comportant la DTD interne pourra être nommé
#     <a href="question-4.xml"><tt>question-4.xml</tt></a>.</p>

# %%
# validation du document XML obtenu
validate('question-4.xml')
# Out:
# True

# %% [markdown]
# ### 4. Transformation du document XML
#
# On se propose maintenant de transformer ce document XML à l'aide de XSLT afin de pouvoir visualiser une partie des informations au format HTML ou XHTML.

# %% [markdown]
# <b>Q5. Développer une première feuille de style</b>
# <div style="background-color:#eef;padding:10px;border-radius:3px">
# Dupliquer le document XML en l'appelant question-5.xml, puis ajouter un lien vers une feuille de style XSL nommée question-5.xsl que vous développerez.
# L'objectif est d'afficher dans un navigateur le document XML via une feuille de style XSL, avec les informations disposées sous forme de tables, en veillant notamment à afficher la ponctualité avec un chiffre significatif après la virgule, et un seul.
# </div>
#
# <div style="margin-top:0.5em;background-color:#fee;padding:10px;border-radius:3px">
# Afin de pouvoir visualiser le résultat d'un document XML transformé par XSL par un navigateur, il est nécessaire pour des raisons de sécurité que les documents soient délivrés via un serveur et non pas directement ouverts depuis le disque local. Le plus simple pour cela est de démarrer un serveur via python, à l'aide de la commande ci-dessous exécutée depuis une fenêtre terminal dans le répertoire de votre BE :
# <code>python -m http.server</code>
#
# Lorsque vous aurez développé la feuille de style correspondante; ceci vous permettra de visualiser votre document à l'adresse : <a href="http://localhost:8000/question-5.xml"><tt>http://localhost:8000/question-5.xml</tt></a>
# </div>
#
# <p>
# <b>N.B.</b> L'obtention d'un document HTML ou XHTML via une transformation XSL n'empêche pas que celui-ci comporte une feuille de style CSS locale, ou fasse appel à une feuille de style CSS externe nommée par exemple
#     <a href="question-5.css"><tt>question-5.css</tt></a>
#     pour son affichage par le navigateur. On pourra appeler la feuille XSLT correspondante
#     <a href="question-5-css.xsl"><tt>question-5-css.xsl</tt></a>
#     et le document XML y faisant appel
#     <a href="http://localhost:8000/question-5-css.xml"><tt>question-5-css.xml</tt></a>.
# </p>

# %% [markdown]
# <b>Q6. Afficher les mois par leur nom et non pas par leur numéro :</b>
# <div style="background-color:#eef;padding:10px;border-radius:3px">
# Créeer un template paramétré pour convertir un numéro de mois en nom de mois en toutes lettres. La nouvelle version de la feuille de style s'appellera <a href="question-6.xsl"><tt>question-6.xsl</tt></a>
# </div>
# <div style="margin-top:0.5em">
#     Voir le résultat : <a href="http://localhost:8000/question-6.xml"><tt>question-6.xml</tt></a>
# </div>

# %% [markdown]
# <b>Q7. Afficher les dates limites dans le titre de la page :</b>
# <div style="background-color:#eef;padding:10px;border-radius:3px">
# Créer des templates paramétrés pour calculer le minimum (resp. le maximum) d'une liste. Utiliser ces templates depuis
#     la feuille de style <a href="question-7.xsl"><tt>question-7.xsl</tt></a>
#     pour afficher un titre du type "Régularité des TGV de septembre 2011 à juin 2015" où les dates sont automatiquement extraites du document XML.
# </div>
# <div style="margin-top:0.5em">
# Voir le résultat : <a href="http://localhost:8000/question-7.xml">question-7.xml</a>
#     </div>

# %% [markdown]
# ### 5. Prise en main de XSL-FO et installation de Apache fop
#
# Afin de pouvoir transformer le document XML de données pour obtenir d'abord un document XSL-FO, puis un rapport papier au format <tt>pdf</tt> il sera nécessaire d'installer l'outil "fop" (Apache Formatting Objects Processor).
#
# <b>Q8. Prise en main de XSL-FO :</b>
# <div style="background-color:#eef;padding:10px;border-radius:3px">
# Consulter le <a href="http://dmolinarius.github.io/demofiles/mod-84/xslfo.pdf">cours sur XSL-FO</a>, puis
# créer une feuille de style XSLT nommée <a href="question-8.xsl"><tt>question-8.xsl</tt></a> qui transforme n'importe quel document XML en un document XSL-FO (toujours le même, quel que soit le contenu du document XML transformé) contenant le message "hello, world".
# </div>

# %% [markdown]
# <b>Q9. Créer un premier document XSL-FO :</b>
# <div style="background-color:#eef;padding:10px;border-radius:3px">
# La transformation XSLT d'un document XML via votre feuille de style peut être très simplement implémentée à l'aide du module lxml ce qui permettra d'admirer le résultat obtenu dans un fichier qui sera nommé <tt>question-9.fo</tt>
# </div>

# %%
from lxml import etree

# document xml vide
xml = etree.XML("<root></root>")

# lecture de la feuille de style xsl
xsl = etree.parse("question-8.xsl")

# transformation du document xml par la feuille de style
transform = etree.XSLT(xsl)
result = transform(xml)

# sérialisation dans un fichier
with open('question-9.fo', 'wb') as f:
    f.write(etree.tostring(result, pretty_print=True, encoding='utf-8'))

# %%
# voir le document question-9.fo
# %pycat question-9.fo
# Out:
# <fo:root xmlns:fo="http://www.w3.org/1999/XSL/Format">
#   <fo:layout-master-set>
#     <fo:simple-page-master master-name="page-unique" page-height="29.7cm" page-width="21cm" margin-top="1.5cm" margin-bottom="2cm" margin-left="2.5cm" margin-right="1cm">
#       <fo:region-body background-color="#CCCCCC"/>
#     </fo:simple-page-master>
#   </fo:layout-master-set>
#   <fo:page-sequence master-reference="page-unique">
#     <fo:flow flow-name="xsl-region-body">
#       <fo:block>Hello World !</fo:block>
#     </fo:flow>
#   </fo:page-sequence>
# </fo:root>

# %% [markdown]
# <b>Q10. Installer fop et obtenir un document pdf :</b>
# <div style="background-color:#eef;padding:10px;border-radius:3px">
# Installer <a href="https://xmlgraphics.apache.org/fop/">Apache FOP</a> et transformer le document <tt>question-9.fo</tt> pour obtenir <a href="question-10.pdf"><tt>question-10.pdf</tt></a>.
# </div>
#
# Exemple de fonction réalisant la transformation depuis le notebook :

# %%
# fonction pour lancer la transformation fop
def run_fop(*fop_args):
    import subprocess
    
    # appel de fop (ajuster éventuellement le chemin d'accès à l'exécutable et au fichier de configuration)
    args = ["fop", *fop_args]
    r = subprocess.run(args,shell=False,stderr=subprocess.PIPE)
    return r.stderr.decode('iso-8859-1')

# %%
# On effectue la transformation
r = run_fop('question-9.fo', 'question-10.pdf')
print(r)
# Out:
# Mar 25, 2024 1:05:07 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #1.

# %%
# Méthode alternative pour lancer fop
# !fop question-9.fo question-10.pdf
# Out:
# Mar 25, 2024 1:05:07 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #1.

# %% [markdown]
# <b>N.B.</b> Il est utile de mentionner ici que fop est non seulement capable d'obtenir comme ci-dessus un document pdf à partir d'un document XSL-FO, mais également d'effectuer au préalable la transformation d'un document xml via xslt avec une feuille de style xsl. Voir pour cela les options de la ligne de commande permettant de lancer fop.

# %%
# !fop --help
# Out:
# /usr/bin/fop [script options] [FOP options]
# Script Options:
#   --help, -h             print this message and FOP help
#   --noconfig             suppress sourcing of /etc/fop.conf,
#                          $HOME/.fop/fop.conf, and $HOME/.foprc
#                          configuration files
#   --execdebug            print FOP exec line generated by this
#                          launch script
# FOP Version 2.9
#
# USAGE
# fop [options] [-fo|-xml] infile [-xsl file] [-awt|-pdf|-mif|-rtf|-tiff|-png|-pcl|-ps|-txt|-at [mime]|-print] <outfile>
#  [OPTIONS]
#   -version          print FOP version and exit
#   -x                dump configuration settings
#   -c cfg.xml        use additional configuration file cfg.xml
#   -l lang           the language to use for user information
#   -nocs             disable complex script features
#   -r                relaxed/less strict validation (where available)
#   -dpi xxx          target resolution in dots per inch (dpi) where xxx is a number
#   -s                for area tree XML, down to block areas only
#   -v                run in verbose mode (currently simply print FOP version and continue)
#
#   -o [password]     PDF file will be encrypted with option owner password
#   -u [password]     PDF file will be encrypted with option user password
#   -noprint          PDF file will be encrypted without printing permission
#   -nocopy           PDF file will be encrypted without copy content permission
#   -noedit           PDF file will be encrypted without edit content permission
#   -noannotations    PDF file will be encrypted without edit annotation permission
#   -nofillinforms    PDF file will be encrypted without fill in interactive form fields permission
#   -noaccesscontent  PDF file will be encrypted without extract text and graphics permission
#   -noassembledoc    PDF file will be encrypted without assemble the document permission
#   -noprinthq        PDF file will be encrypted without print high quality permission
#   -a                enables accessibility features (Tagged PDF etc., default off)
#   -pdfprofile prof  PDF file will be generated with the specified profile
#                     (Examples for prof: PDF/A-1b or PDF/X-3:2003)
#
#   -conserve         enable memory-conservation policy (trades memory-consumption for disk I/O)
#                     (Note: currently only influences whether the area tree is serialized.)
#
#   -cache            specifies a file/directory path location for the font cache file
#   -flush            flushes the current font cache file
#
#  [INPUT]
#   infile            xsl:fo input file (the same as the next)
#                     (use '-' for infile to pipe input from stdin)
#   -fo  infile       xsl:fo input file
#   -xml infile       xml input file, must be used together with -xsl
#   -atin infile      area tree input file
#   -ifin infile      intermediate format input file
#   -imagein infile   image input file (piping through stdin not supported)
#   -xsl stylesheet   xslt stylesheet
#
#   -param name value <value> to use for parameter <name> in xslt stylesheet
#                     (repeat '-param name value' for each parameter)
#
#   -catalog          use catalog resolver for input XML and XSLT files
#  [OUTPUT]
#   outfile           input will be rendered as PDF into outfile
#                     (use '-' for outfile to pipe output to stdout)
#   -pdf outfile      input will be rendered as PDF (outfile req'd)
#   -pdfa1b outfile   input will be rendered as PDF/A-1b compliant PDF
#                     (outfile req'd, same as "-pdf outfile -pdfprofile PDF/A-1b")
#   -awt              input will be displayed on screen
#   -rtf outfile      input will be rendered as RTF (outfile req'd)
#   -pcl outfile      input will be rendered as PCL (outfile req'd)
#   -ps outfile       input will be rendered as PostScript (outfile req'd)
#   -afp outfile      input will be rendered as AFP (outfile req'd)
#   -tiff outfile     input will be rendered as TIFF (outfile req'd)
#   -png outfile      input will be rendered as PNG (outfile req'd)
#   -txt outfile      input will be rendered as plain text (outfile req'd)
#   -at [mime] out    representation of area tree as XML (outfile req'd)
#                     specify optional mime output to allow the AT to be converted
#                     to final format later
#   -if [mime] out    representation of document in intermediate format XML (outfile req'd)
#                     specify optional mime output to allow the IF to be converted
#                     to final format later
#   -print            input file will be rendered and sent to the printer
#                     see options with "-print help"
#   -out mime outfile input will be rendered using the given MIME type
#                     (outfile req'd) Example: "-out application/pdf D:\out.pdf"
#                     (Tip: "-out list" prints the list of supported MIME types and exits)
#   -svg outfile      input will be rendered as an SVG slides file (outfile req'd)
#                     Experimental feature - requires additional fop-sandbox.jar.
#
#   -foout outfile    input will only be XSL transformed. The intermediate
#                     XSL-FO file is saved and no rendering is performed.
#                     (Only available if you use -xml and -xsl parameters)
#
#
#  [Examples]
#   fop foo.fo foo.pdf
#   fop -fo foo.fo -pdf foo.pdf (does the same as the previous line)
#   fop -xml foo.xml -xsl foo.xsl -pdf foo.pdf
#   fop -xml foo.xml -xsl foo.xsl -foout foo.fo
#   fop -xml - -xsl foo.xsl -pdf -
#   fop foo.fo -mif foo.mif
#   fop foo.fo -rtf foo.rtf
#   fop foo.fo -print
#   fop foo.fo -awt

# %% [markdown]
# ### 6. Création d'un rapport
#
# Maintenant que la chaîne de production est maîtrisée, l'objectif sera de créer un rapport au format pdf, à partir des données du document de base <a href="question-3.xml"><tt>question-3.xml</tt></a> qui servira de source pour toute la suite du BE.
#
# <b>Q11. Liste des axes :</b>
# <div style="background-color:#eef;padding:10px;border-radius:3px">
# Développer une feuille de style XSL qui transforme ce document de manière à obtenir un document <tt>pdf</tt> listant le nom des axes sous forme de titres.
# </div>
#
# On nommera les documents demandés
# <a href="question-11.xsl"><tt>question-11.xsl</tt></a> et
# <a href="question-11.pdf"><tt>question-11.pdf</tt></a>.

# %%
# Transformation pour obtention du document pdf
r = run_fop('-xml', 'question-3.xml', '-xsl', 'question-11.xsl', '-pdf', 'question-11.pdf')
print(r)
# Out:
# Mar 25, 2024 1:05:10 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #1.
# Mar 25, 2024 1:05:10 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #2.
# Mar 25, 2024 1:05:10 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #3.
# Mar 25, 2024 1:05:10 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #4.

# %% [markdown]
# <b>Q12. Page de titre :</b>
# <div style="background-color:#eef;padding:10px;border-radius:3px">
# Ajouter une page de titre. En profiter pour y mentionner vos noms et la date d'édition en passant des variables appropriées au moteur XSLT via la ligne de commande de fop.
# </div>
#
# Les documents demandés seront nommés
# <a href="question-12.xsl"><tt>question-12.xsl</tt></a> et
# <a href="question-12.pdf"><tt>question-12.pdf</tt></a>.

# %%
def run_transform(args):
    from datetime import datetime

    # date de la transformation
    d = datetime.now()
    date_components = [
        ['lundi','mardi','mercredi','jeudi','vendredi','samedi','dimanche'][d.weekday()],
        d.day,
        ['janvier', 'février', 'mars', 'avril', 'mai','juin', 'juillet',
         'août', 'septembre', 'octobre', 'novembre', 'décembre'][d.month-1],
        d.year
    ]
    date="{} {} {} {}".format(*date_components)

    # Transformation pour obtention du document pdf
    fop_args = [
        '-param', 'date', date,
        '-param', 'hour', str(d.hour),
        '-param', 'minutes', str(d.minute),
        '-param', 'author', 'Matías Duhalde',
        *args
    ]
    return run_fop(*fop_args)

# %%
r = run_transform([
    '-xml', 'question-3.xml',
    '-xsl', 'question-12.xsl',
    '-pdf', 'question-12.pdf'
])
print(r)
# Out:
# Mar 25, 2024 1:22:04 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: Font "Symbol,normal,700" not found. Substituting with "Symbol,normal,400".
# Mar 25, 2024 1:22:04 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: Font "ZapfDingbats,normal,700" not found. Substituting with "ZapfDingbats,normal,400".
# Mar 25, 2024 1:22:04 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #1.
# Mar 25, 2024 1:22:04 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #2.
# Mar 25, 2024 1:22:04 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #3.
# Mar 25, 2024 1:22:04 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #4.
# Mar 25, 2024 1:22:04 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #5.

# %% [markdown]
# <b>Q13. Statistiques :</b>
# <div style="background-color:#eef;padding:10px;border-radius:3px">
# Pour chacun des couples gare de départ / gare d'arrivée, créer un tableau avec les statistiques de la ligne, en évitant que les tableaux puissent être coupés par un saut de page. Ne pas oublier d'afficher les statistiques dans l'ordre du calendrier, et non pas dans l'ordre du document source...
# </div>
# <p>
# Les documents demandés seront nommés
# <a href="question-13.xsl"><tt>question-13.xsl</tt></a>,
# <a href="question-13.pdf"><tt>question-13.pdf</tt></a>.
# </p>

# %%
r = run_transform(['-xml','question-3.xml', '-xsl','question-13.xsl', '-pdf','question-13.pdf'])
print(r)
# Out:
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: Font "Symbol,normal,700" not found. Substituting with "Symbol,normal,400".
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: Font "ZapfDingbats,normal,700" not found. Substituting with "ZapfDingbats,normal,400".
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #1.
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 25 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 23 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 21 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 19 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 17 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 15 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 13 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 11 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 9 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 7 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 5 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 3 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #2.
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #3.
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #4.
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #5.
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #6.
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #7.
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #8.
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #9.
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #10.
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #11.
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #12.
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #13.
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #14.
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #15.
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #16.
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #17.
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #18.
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #19.
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #20.
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #21.
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #22.
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #23.
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #24.
# Mar 25, 2024 1:26:07 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #25.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 113 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 111 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 109 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 107 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 105 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 103 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 101 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 99 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 97 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 95 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 93 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 91 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 89 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 87 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 85 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 83 exceed its viewport by 195322 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 81 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 79 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 77 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 75 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 73 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 71 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 69 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 67 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 65 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 63 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 61 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 59 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 57 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 55 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 53 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 51 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 49 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 47 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 45 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 43 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 41 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 39 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 37 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 35 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 33 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 31 exceed its viewport by 195322 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 29 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 27 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #26.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #27.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #28.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #29.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #30.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #31.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #32.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #33.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #34.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #35.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #36.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #37.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #38.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #39.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #40.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #41.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #42.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #43.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #44.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #45.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #46.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #47.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #48.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #49.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #50.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #51.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #52.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #53.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #54.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #55.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #56.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #57.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #58.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #59.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #60.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #61.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #62.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #63.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #64.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #65.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #66.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #67.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #68.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #69.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #70.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #71.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #72.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #73.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #74.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #75.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #76.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #77.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #78.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #79.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #80.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #81.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #82.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #83.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #84.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #85.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #86.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #87.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #88.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #89.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #90.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #91.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #92.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #93.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #94.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #95.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #96.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #97.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #98.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #99.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #100.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #101.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #102.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #103.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #104.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #105.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #106.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #107.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #108.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #109.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #110.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #111.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #112.
# Mar 25, 2024 1:26:08 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #113.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 181 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 179 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 177 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 175 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 173 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 171 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 169 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 167 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 165 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 163 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 161 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 159 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 157 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 155 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 153 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 151 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 149 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 147 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 145 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 143 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 141 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 139 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 137 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 135 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 133 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 131 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 129 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 127 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 125 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 123 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 121 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 119 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 117 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 115 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #114.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #115.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #116.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #117.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #118.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #119.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #120.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #121.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #122.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #123.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #124.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #125.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #126.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #127.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #128.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #129.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #130.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #131.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #132.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #133.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #134.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #135.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #136.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #137.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #138.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #139.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #140.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #141.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #142.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #143.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #144.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #145.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #146.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #147.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #148.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #149.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #150.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #151.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #152.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #153.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #154.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #155.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #156.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #157.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #158.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #159.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #160.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #161.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #162.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #163.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #164.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #165.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #166.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #167.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #168.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #169.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #170.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #171.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #172.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #173.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #174.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #175.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #176.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #177.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #178.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #179.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #180.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #181.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:block line 1 exceed the available area in the inline-progression direction by 264 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 201 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 199 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 197 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 195 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 193 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 191 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 189 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 187 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 185 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# WARNING: The contents of fo:region-body on page 183 exceed its viewport by 305322 millipoints. (No context info available)
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #182.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #183.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #184.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #185.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #186.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #187.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #188.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #189.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #190.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #191.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #192.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #193.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #194.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #195.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #196.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #197.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #198.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #199.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #200.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #201.
# Mar 25, 2024 1:26:09 PM org.apache.fop.apps.FOUserAgent processEvent
# INFO: Rendered page #202.

# %% [markdown]
# <b>Q14. Commentaires :</b>
# <div style="background-color:#eef;padding:10px;border-radius:3px">
# Faire figurer les commentaires non vides là aussi dans l'ordre du calendrier.
# </div>
#
# Les documents demandés seront nommés
# <a href="question-14.xsl"><tt>question-14.xsl</tt></a> et
# <a href="question-14.pdf"><tt>question-14.pdf</tt></a>.

# %%
r = run_transform(['-xml','question-3.xml', '-xsl','question-14.xsl', '-pdf','question-14.pdf'])
print(r)
# Out:
# USAGE
# fop [options] [-fo|-xml] infile [-xsl file] [-awt|-pdf|-mif|-rtf|-tiff|-png|-pcl|-ps|-txt|-at [mime]|-print] <outfile>
#  [OPTIONS]
#   -version          print FOP version and exit
#   -x                dump configuration settings
#   -c cfg.xml        use additional configuration file cfg.xml
#   -l lang           the language to use for user information
#   -nocs             disable complex script features
#   -r                relaxed/less strict validation (where available)
#   -dpi xxx          target resolution in dots per inch (dpi) where xxx is a number
#   -s                for area tree XML, down to block areas only
#   -v                run in verbose mode (currently simply print FOP version and continue)
#
#   -o [password]     PDF file will be encrypted with option owner password
#   -u [password]     PDF file will be encrypted with option user password
#   -noprint          PDF file will be encrypted without printing permission
#   -nocopy           PDF file will be encrypted without copy content permission
#   -noedit           PDF file will be encrypted without edit content permission
#   -noannotations    PDF file will be encrypted without edit annotation permission
#   -nofillinforms    PDF file will be encrypted without fill in interactive form fields permission
#   -noaccesscontent  PDF file will be encrypted without extract text and graphics permission
#   -noassembledoc    PDF file will be encrypted without assemble the document permission
#   -noprinthq        PDF file will be encrypted without print high quality permission
#   -a                enables accessibility features (Tagged PDF etc., default off)
#   -pdfprofile prof  PDF file will be generated with the specified profile
#                     (Examples for prof: PDF/A-1b or PDF/X-3:2003)
#
#   -conserve         enable memory-conservation policy (trades memory-consumption for disk I/O)
#                     (Note: currently only influences whether the area tree is serialized.)
#
#   -cache            specifies a file/directory path location for the font cache file
#   -flush            flushes the current font cache file
#
#  [INPUT]
#   infile            xsl:fo input file (the same as the next)
#                     (use '-' for infile to pipe input from stdin)
#   -fo  infile       xsl:fo input file
#   -xml infile       xml input file, must be used together with -xsl
#   -atin infile      area tree input file
#   -ifin infile      intermediate format input file
#   -imagein infile   image input file (piping through stdin not supported)
#   -xsl stylesheet   xslt stylesheet
#
#   -param name value <value> to use for parameter <name> in xslt stylesheet
#                     (repeat '-param name value' for each parameter)
#
#   -catalog          use catalog resolver for input XML and XSLT files
#  [OUTPUT]
#   outfile           input will be rendered as PDF into outfile
#                     (use '-' for outfile to pipe output to stdout)
#   -pdf outfile      input will be rendered as PDF (outfile req'd)
#   -pdfa1b outfile   input will be rendered as PDF/A-1b compliant PDF
#                     (outfile req'd, same as "-pdf outfile -pdfprofile PDF/A-1b")
#   -awt              input will be displayed on screen
#   -rtf outfile      input will be rendered as RTF (outfile req'd)
#   -pcl outfile      input will be rendered as PCL (outfile req'd)
#   -ps outfile       input will be rendered as PostScript (outfile req'd)
#   -afp outfile      input will be rendered as AFP (outfile req'd)
#   -tiff outfile     input will be rendered as TIFF (outfile req'd)
#   -png outfile      input will be rendered as PNG (outfile req'd)
#   -txt outfile      input will be rendered as plain text (outfile req'd)
#   -at [mime] out    representation of area tree as XML (outfile req'd)
#                     specify optional mime output to allow the AT to be converted
#                     to final format later
#   -if [mime] out    representation of document in intermediate format XML (outfile req'd)
#                     specify optional mime output to allow the IF to be converted
#                     to final format later
#   -print            input file will be rendered and sent to the printer
#                     see options with "-print help"
#   -out mime outfile input will be rendered using the given MIME type
#                     (outfile req'd) Example: "-out application/pdf D:\out.pdf"
#                     (Tip: "-out list" prints the list of supported MIME types and exits)
#   -svg outfile      input will be rendered as an SVG slides file (outfile req'd)
#                     Experimental feature - requires additional fop-sandbox.jar.
#
#   -foout outfile    input will only be XSL transformed. The intermediate
#                     XSL-FO file is saved and no rendering is performed.
#                     (Only available if you use -xml and -xsl parameters)
#
#
#  [Examples]
#   fop foo.fo foo.pdf
#   fop -fo foo.fo -pdf foo.pdf (does the same as the previous line)
#   fop -xml foo.xml -xsl foo.xsl -pdf foo.pdf
#   fop -xml foo.xml -xsl foo.xsl -foout foo.fo
#   fop -xml - -xsl foo.xsl -pdf -
#   fop foo.fo -mif foo.mif
#   fop foo.fo -rtf foo.rtf
#   fop foo.fo -print
#   fop foo.fo -awt
#
# Mar 25, 2024 12:19:59 PM FOP startFOP
# SEVERE: Exception
# java.io.FileNotFoundException: Error: xsl file /home/tracert6/Documents/BE-XML/question-14.xsl not found
# 	at org.apache.fop.cli.CommandLineOptions.checkSettings(CommandLineOptions.java:957)
# 	at org.apache.fop.cli.CommandLineOptions.parse(CommandLineOptions.java:174)
# 	at org.apache.fop.cli.Main.startFOP(Main.java:171)
# 	at org.apache.fop.cli.Main.startFOP(Main.java:150)
# 	at org.apache.fop.cli.Main.main(Main.java:219)

# %% [markdown]
# <b>Q15. Améliorer <i>ad libitum</i> :</b>
# <div style="background-color:#eef;padding:10px;border-radius:3px">
# Numéroter les pages, ajouter un graphique SVG par couple gare de départ / gare d'arrivée,
# créer un sommaire cliquable renvoyant directement à la page concernée...
# </div>
#
# Les documents demandés seront nommés
# <a href="question-15.xsl"><tt>question-15.xsl</tt></a> et
# <a href="question-15.pdf"><tt>question-15.pdf</tt></a>.

# %%
r = run_transform(['-xml','question-3.xml', '-xsl','question-15.xsl', '-pdf','question-15.pdf'])
print(r)
# Out:
# mars 20, 2024 9:37:52 PM org.apache.fop.apps.FopConfParser configure
# INFOS: Default page-height set to: 11.00in
# mars 20, 2024 9:37:52 PM org.apache.fop.apps.FopConfParser configure
# INFOS: Default page-width set to: 8.50in
# mars 20, 2024 9:38:01 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #1.
# mars 20, 2024 9:38:01 PM org.apache.fop.events.LoggingEventListener processEvent
# AVERTISSEMENT: Font "Symbol,normal,700" not found. Substituting with "Symbol,normal,400".
# mars 20, 2024 9:38:01 PM org.apache.fop.events.LoggingEventListener processEvent
# AVERTISSEMENT: Font "ZapfDingbats,normal,700" not found. Substituting with "ZapfDingbats,normal,400".
# mars 20, 2024 9:38:02 PM org.apache.fop.events.LoggingEventListener processEvent
# AVERTISSEMENT: Font "Franklin Gothic Medium,italic,700" not found. Substituting with "Franklin Gothic Medium,italic,500".
# mars 20, 2024 9:38:08 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #2.
# mars 20, 2024 9:38:08 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #3.
# mars 20, 2024 9:38:08 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #4.
# mars 20, 2024 9:38:08 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #5.
# mars 20, 2024 9:38:08 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #6.
# mars 20, 2024 9:38:08 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #7.
# mars 20, 2024 9:38:08 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #8.
# mars 20, 2024 9:38:08 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #9.
# mars 20, 2024 9:38:09 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #10.
# mars 20, 2024 9:38:09 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #11.
# mars 20, 2024 9:38:09 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #12.
# mars 20, 2024 9:38:09 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #13.
# mars 20, 2024 9:38:09 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #14.
# mars 20, 2024 9:38:09 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #15.
# mars 20, 2024 9:38:09 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #16.
# mars 20, 2024 9:38:09 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #17.
# mars 20, 2024 9:38:09 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #18.
# mars 20, 2024 9:38:09 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #19.
# mars 20, 2024 9:38:09 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #20.
# mars 20, 2024 9:38:09 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #21.
# mars 20, 2024 9:38:09 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #22.
# mars 20, 2024 9:38:09 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #23.
# mars 20, 2024 9:38:09 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #24.
# mars 20, 2024 9:38:10 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #25.
# mars 20, 2024 9:38:10 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #26.
# mars 20, 2024 9:38:10 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #27.
# mars 20, 2024 9:38:10 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #28.
# mars 20, 2024 9:38:10 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #29.
# mars 20, 2024 9:38:10 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #30.
# mars 20, 2024 9:38:10 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #31.
# mars 20, 2024 9:38:10 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #32.
# mars 20, 2024 9:38:10 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #33.
# mars 20, 2024 9:38:10 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #34.
# mars 20, 2024 9:38:10 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #35.
# mars 20, 2024 9:38:10 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #36.
# mars 20, 2024 9:38:10 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #37.
# mars 20, 2024 9:38:10 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #38.
# mars 20, 2024 9:38:10 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #39.
# mars 20, 2024 9:38:11 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #40.
# mars 20, 2024 9:38:11 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #41.
# mars 20, 2024 9:38:11 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #42.
# mars 20, 2024 9:38:11 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #43.
# mars 20, 2024 9:38:11 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #44.
# mars 20, 2024 9:38:11 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #45.
# mars 20, 2024 9:38:11 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #46.
# mars 20, 2024 9:38:11 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #47.
# mars 20, 2024 9:38:11 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #48.
# mars 20, 2024 9:38:11 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #49.
# mars 20, 2024 9:38:11 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #50.
# mars 20, 2024 9:38:11 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #51.
# mars 20, 2024 9:38:11 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #52.
# mars 20, 2024 9:38:11 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #53.
# mars 20, 2024 9:38:11 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #54.
# mars 20, 2024 9:38:11 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #55.
# mars 20, 2024 9:38:11 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #56.
# mars 20, 2024 9:38:11 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #57.
# mars 20, 2024 9:38:11 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #58.
# mars 20, 2024 9:38:11 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #59.
# mars 20, 2024 9:38:11 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #60.
# mars 20, 2024 9:38:11 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #61.
# mars 20, 2024 9:38:12 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #62.
# mars 20, 2024 9:38:12 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #63.
# mars 20, 2024 9:38:12 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #64.
# mars 20, 2024 9:38:12 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #65.
# mars 20, 2024 9:38:12 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #66.
# mars 20, 2024 9:38:12 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #67.
# mars 20, 2024 9:38:12 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #68.
# mars 20, 2024 9:38:12 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #69.
# mars 20, 2024 9:38:12 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #70.
# mars 20, 2024 9:38:12 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #71.
# mars 20, 2024 9:38:12 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #72.
# mars 20, 2024 9:38:12 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #73.
# mars 20, 2024 9:38:12 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #74.
# mars 20, 2024 9:38:12 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #75.
# mars 20, 2024 9:38:12 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #76.
# mars 20, 2024 9:38:12 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #77.
# mars 20, 2024 9:38:12 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #78.
# mars 20, 2024 9:38:12 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #79.
# mars 20, 2024 9:38:13 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #80.
# mars 20, 2024 9:38:13 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #81.
# mars 20, 2024 9:38:13 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #82.
# mars 20, 2024 9:38:13 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #83.
# mars 20, 2024 9:38:13 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #84.
# mars 20, 2024 9:38:13 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #85.
# mars 20, 2024 9:38:13 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #86.
# mars 20, 2024 9:38:13 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #87.
# mars 20, 2024 9:38:13 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #88.
# mars 20, 2024 9:38:13 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #89.
# mars 20, 2024 9:38:13 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #90.
# mars 20, 2024 9:38:13 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #91.
# mars 20, 2024 9:38:13 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #92.
# mars 20, 2024 9:38:13 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #93.
# mars 20, 2024 9:38:13 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #94.
# mars 20, 2024 9:38:13 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #95.
# mars 20, 2024 9:38:13 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #96.
# mars 20, 2024 9:38:13 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #97.
# mars 20, 2024 9:38:13 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #98.
# mars 20, 2024 9:38:13 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #99.
# mars 20, 2024 9:38:13 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #100.
# mars 20, 2024 9:38:14 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #101.
# mars 20, 2024 9:38:14 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #102.
# mars 20, 2024 9:38:14 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #103.
# mars 20, 2024 9:38:14 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #104.
# mars 20, 2024 9:38:14 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #105.
# mars 20, 2024 9:38:14 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #106.
# mars 20, 2024 9:38:14 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #107.
# mars 20, 2024 9:38:14 PM org.apache.fop.events.LoggingEventListener processEvent
# INFOS: Rendered page #108.
